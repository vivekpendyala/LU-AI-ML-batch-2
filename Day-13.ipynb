# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import seaborn as sb

# %%
# %matplotlib inline

# %% [markdown]
# # Version check of the modules

# %%
print(np.__version__)
print(pd.__version__)
print(mp.__version__)
print(sb.__version__)
# Out:
# 1.18.1
# 1.0.1
# 3.1.3
# 0.10.0

# %% [markdown]
# # changing the current working directory

# %%
import os
os.chdir('C:\\Users\VIVEK\Desktop\AI-ML\CSV files')

# %%
data = pd.read_csv('creditcard.csv')
data = pd.DataFrame(data)
print(data)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# # checking different observation on the data
#
# like info , describe, mean , max etc..

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
data.min()       # Getting the minimum values of all the columns
# Out:
# Time            0
# V1       -56.4075
# V2       -72.7157
# V3       -48.3256
# V4       -5.68317
# V5       -113.743
# V6       -26.1605
# V7       -43.5572
# V8       -73.2167
# V9       -13.4341
# V10      -24.5883
# V11      -4.79747
# V12      -18.6837
# V13      -5.79188
# V14      -19.2143
# V15      -4.49894
# V16      -14.1299
# V17      -25.1628
# V18      -9.49875
# V19      -7.21353
# V20      -54.4977
# V21      -34.8304
# V22      -10.9331
# V23      -44.8077
# V24      -2.83663
# V25      -10.2954
# V26      -2.60455
# V27      -22.5657
# V28      -15.4301
# Amount          0
# Class         '0'
# dtype: object

# %%
data['V19'].min()       # Getting the minimum value of a specified column.
# Out:
# -7.21352743017759

# %%
data.max()             # Getting the maximum value of all the columns
# Out:
# Time       172792
# V1        2.45493
# V2        22.0577
# V3        9.38256
# V4        16.8753
# V5        34.8017
# V6        73.3016
# V7        120.589
# V8        20.0072
# V9         15.595
# V10       23.7451
# V11       12.0189
# V12       7.84839
# V13       7.12688
# V14       10.5268
# V15       8.87774
# V16       17.3151
# V17       9.25353
# V18       5.04107
# V19       5.59197
# V20       39.4209
# V21       27.2028
# V22       10.5031
# V23       22.5284
# V24       4.58455
# V25       7.51959
# V26       3.51735
# V27       31.6122
# V28       33.8478
# Amount    25691.2
# Class         '1'
# dtype: object

# %%
data.mean()                  # Getting the mean of all the columns
# Out:
# Time      9.481386e+04
# V1        3.919560e-15
# V2        5.688174e-16
# V3       -8.769071e-15
# V4        2.782312e-15
# V5       -1.552563e-15
# V6        2.010663e-15
# V7       -1.694249e-15
# V8       -1.927028e-16
# V9       -3.137024e-15
# V10       1.768627e-15
# V11       9.170318e-16
# V12      -1.810658e-15
# V13       1.693438e-15
# V14       1.479045e-15
# V15       3.482336e-15
# V16       1.392007e-15
# V17      -7.528491e-16
# V18       4.328772e-16
# V19       9.049732e-16
# V20       5.085503e-16
# V21       1.537294e-16
# V22       7.959909e-16
# V23       5.367590e-16
# V24       4.458112e-15
# V25       1.453003e-15
# V26       1.699104e-15
# V27      -3.660161e-16
# V28      -1.206049e-16
# Amount    8.834962e+01
# dtype: float64

# %%
data.median()                 # Getting the median of all the columns
# Out:
# Time      84692.000000
# V1            0.018109
# V2            0.065486
# V3            0.179846
# V4           -0.019847
# V5           -0.054336
# V6           -0.274187
# V7            0.040103
# V8            0.022358
# V9           -0.051429
# V10          -0.092917
# V11          -0.032757
# V12           0.140033
# V13          -0.013568
# V14           0.050601
# V15           0.048072
# V16           0.066413
# V17          -0.065676
# V18          -0.003636
# V19           0.003735
# V20          -0.062481
# V21          -0.029450
# V22           0.006782
# V23          -0.011193
# V24           0.040976
# V25           0.016594
# V26          -0.052139
# V27           0.001342
# V28           0.011244
# Amount       22.000000
# dtype: float64

# %% [markdown]
# # Checking for null values

# %% [markdown]
# --> Checking null values of all the rows and columns

# %%
data.isnull()
# Out:
#          Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 284802  False  False  False  False  False  False  False  False  False  False
# 284803  False  False  False  False  False  False  False  False  False  False
# 284804  False  False  False  False  False  False  False  False  False  False
# 284805  False  False  False  False  False  False  False  False  False  False
# 284806  False  False  False  False  False  False  False  False  False  False
#
# ...

# %% [markdown]
# --> Checking the null value for specified columns

# %%
data['V1'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Name: V1, Length: 284807, dtype: bool

# %% [markdown]
# --To checking null values in the specified columns only.

# %%
data[['V1','V2']].isnull()
# Out:
#            V1     V2
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# ...       ...    ...
# 284802  False  False
# 284803  False  False
# 284804  False  False
# 284805  False  False
# 284806  False  False
#
# [284807 rows x 2 columns]

# %% [markdown]
# # Checking duplicate values

# %%
v = data.duplicated(keep=False)
print(v)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Length: 284807, dtype: bool

# %% [markdown]
# # Using GroupBy

# %%
g = data.groupby('Time')      # Grouping the data with respect to time.

# %%
for i,j in g:
    print(i ,'\n', j)
# Out:
# 0.0
#     Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    '0'
# 1  0.125895 -0.008983  0.014724    2.69    '0'
#
# [2 rows x 31 columns]
# 1.0
#     Time        V1        V2        V3        V4        V5        V6        V7  \
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
#
# ...

# %%
g.min()
# Out:
#                  V1         V2        V3        V4        V5        V6  \
# Time
# 0.0       -1.359807  -0.072781  0.166480  0.448154 -0.338321 -0.082361
# 1.0       -1.358354  -1.340163  1.773209 -0.863291 -0.503198  1.247203
# 2.0       -1.158233   0.877737  1.141109 -0.168252 -0.407193 -0.029728
# 4.0        1.229658   0.141004  0.045371  1.202613  0.191881  0.272708
# 7.0       -0.894286   0.286157 -0.113192 -0.492199  0.948934  0.428118
# ...             ...        ...       ...       ...       ...       ...
# 172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314 -0.235973
# 172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 172788.0  -0.240440  -0.301254 -3.249640 -0.557828 -0.377961  0.623708
# 172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#                 V7        V8        V9       V10  ...       V21       V22  \
# ...

# %% [markdown]
# # Using head and tail with default

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# # Changing the default value of head and tail

# %%
data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
data.tail(10)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284797  172782.0  -0.241923   0.712247  0.399806 -0.463406  0.244531
# 284798  172782.0   0.219529   0.881246 -0.635891  0.960928 -0.152971
# 284799  172783.0  -1.775135  -0.004235  1.189786  0.331096  1.196063
# 284800  172784.0   2.039560  -0.175233 -1.196825  0.234580 -0.008713
# 284801  172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284797 -1.343668  0.929369 -0.206210  0.106234  ... -0.228876 -0.514376
# ...

# %% [markdown]
# # Basic Plots

# %%
sb.barplot(x=['Time','V1'],data=data[['Time','V1']])

# %%
sb.boxplot(x=['Time','V1'],data=data[['Time','V1']])

# %%
sb.scatterplot(data=data[['Time','V1']])

# %%
plt.scatter(data['Time'] ,data['V1'])

# %%
plt.scatter(data['Time'] ,data['V2'])

# %%
plt.scatter(data['Time'] ,data['V3'])

# %%
plt.scatter(data['Time'] ,data['V4'])

# %%
plt.scatter(data['Time'] ,data['V5'])

# %%
plt.scatter(data['Time'] ,data['V6'])

# %%
plt.scatter(data['Time'] ,data['V7'])

# %%
plt.scatter(data['Time'] ,data['V8'])

# %% [markdown]
# # Using Histogram to plot different columns

# %%
import matplotlib.pyplot as plt

plt.hist(data['Time'], rwidth=0.5)
# Out:
# (array([10510., 16955., 38526., 38550., 40243., 10145., 17161., 38951.,
#         40779., 32987.]),
#  array([     0. ,  17279.2,  34558.4,  51837.6,  69116.8,  86396. ,
#         103675.2, 120954.4, 138233.6, 155512.8, 172792. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V1'])
# Out:
# (array([1.00000e+00, 1.00000e+00, 3.00000e+00, 1.80000e+01, 3.00000e+01,
#         8.10000e+01, 1.84000e+02, 8.89000e+02, 9.46200e+03, 2.74138e+05]),
#  array([-56.40750963, -50.52126567, -44.63502171, -38.74877774,
#         -32.86253378, -26.97628982, -21.09004586, -15.2038019 ,
#          -9.31755793,  -3.43131397,   2.45492999]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V2'])
# Out:
# (array([2.00000e+00, 1.00000e+00, 5.00000e+00, 1.70000e+01, 4.60000e+01,
#         1.77000e+02, 1.46300e+03, 2.78631e+05, 4.42700e+03, 3.80000e+01]),
#  array([-72.71572756, -63.23838191, -53.76103625, -44.2836906 ,
#         -34.80634494, -25.32899929, -15.85165363,  -6.37430798,
#           3.10303768,  12.58038334,  22.05772899]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V3'])
# Out:
# (array([1.00000e+00, 0.00000e+00, 5.00000e+00, 1.70000e+01, 3.80000e+01,
#         6.80000e+01, 3.50000e+02, 1.81850e+04, 2.66017e+05, 1.26000e+02]),
#  array([-48.32558936, -42.55477458, -36.7839598 , -31.01314502,
#         -25.24233024, -19.47151546, -13.70070069,  -7.92988591,
#          -2.15907113,   3.61174365,   9.38255843]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V4'], rwidth=0.8)
# Out:
# (array([1.5240e+03, 5.0190e+04, 1.8203e+05, 4.3107e+04, 7.5010e+03,
#         3.1900e+02, 8.3000e+01, 4.5000e+01, 4.0000e+00, 4.0000e+00]),
#  array([-5.6831712 , -3.42731967, -1.17146815,  1.08438337,  3.34023489,
#          5.59608642,  7.85193794, 10.10778946, 12.36364099, 14.61949251,
#         16.87534403]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V5'], rwidth=0.8)
# Out:
# (array([1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 2.00000e+00,
#         1.10000e+01, 2.52000e+02, 2.83733e+05, 7.87000e+02, 2.10000e+01]),
#  array([-113.74330671,  -98.88880945,  -84.03431219,  -69.17981493,
#          -54.32531768,  -39.47082042,  -24.61632316,   -9.7618259 ,
#            5.09267136,   19.94716862,   34.80166588]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V6'], rwidth=0.8)
# Out:
# (array([1.30000e+01, 1.71000e+02, 2.77728e+05, 6.87100e+03, 2.20000e+01,
#         1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([-26.16050594, -16.21429279,  -6.26807964,   3.67813351,
#          13.62434666,  23.57055981,  33.51677295,  43.4629861 ,
#          53.40919925,  63.3554124 ,  73.30162555]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V7'], rwidth=0.8)
# Out:
# (array([1.10000e+01, 2.05000e+02, 2.84016e+05, 5.51000e+02, 2.20000e+01,
#         1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([-43.55724157, -27.14256802, -10.72789447,   5.68677908,
#          22.10145264,  38.51612619,  54.93079974,  71.34547329,
#          87.76014684, 104.17482039, 120.58949395]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V8'], rwidth=0.8)
# Out:
# (array([1.00000e+00, 0.00000e+00, 3.00000e+00, 1.20000e+01, 1.20000e+01,
#         1.09000e+02, 7.66000e+02, 2.76426e+05, 7.44300e+03, 3.50000e+01]),
#  array([-73.21671846, -63.89432577, -54.57193309, -45.24954041,
#         -35.92714773, -26.60475505, -17.28236236,  -7.95996968,
#           1.362423  ,  10.68481568,  20.00720837]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V9'], rwidth=0.8)
# Out:
# (array([4.00000e+00, 1.90000e+01, 6.00000e+01, 1.27130e+04, 2.32671e+05,
#         3.81630e+04, 1.05400e+03, 1.17000e+02, 5.00000e+00, 1.00000e+00]),
#  array([-13.43406632, -10.53116023,  -7.62825413,  -4.72534804,
#          -1.82244195,   1.08046414,   3.98337024,   6.88627633,
#           9.78918242,  12.69208851,  15.59499461]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V10'], rwidth=0.8)
# Out:
# (array([9.0000e+00, 1.8000e+01, 7.7000e+01, 1.7700e+02, 8.5797e+04,
#         1.9698e+05, 1.4860e+03, 2.5900e+02, 3.0000e+00, 1.0000e+00]),
#  array([-24.58826244, -19.75492258, -14.92158273, -10.08824287,
#          -5.25490301,  -0.42156316,   4.4117767 ,   9.24511655,
#          14.07845641,  18.91179626,  23.74513612]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V11'], rwidth=0.8)
# Out:
# (array([8.90000e+01, 2.03150e+04, 1.48592e+05, 1.09621e+05, 5.85900e+03,
#         1.81000e+02, 6.40000e+01, 4.70000e+01, 2.90000e+01, 1.00000e+01]),
#  array([-4.79747346, -3.1158348 , -1.43419614,  0.24744253,  1.92908119,
#          3.61071986,  5.29235852,  6.97399719,  8.65563585, 10.33727452,
#         12.01891318]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V12'], rwidth=0.8)
# Out:
# (array([2.10000e+01, 4.70000e+01, 3.50000e+01, 6.90000e+01, 1.27000e+02,
#         4.60600e+03, 1.00696e+05, 1.78826e+05, 3.79000e+02, 1.00000e+00]),
#  array([-18.68371463, -16.03050396, -13.37729329, -10.72408262,
#          -8.07087195,  -5.41766128,  -2.76445061,  -0.11123994,
#           2.54197073,   5.1951814 ,   7.84839208]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V13'], rwidth=0.8)
# Out:
# (array([1.00000e+00, 1.99000e+02, 7.28600e+03, 6.58590e+04, 1.40729e+05,
#         6.33980e+04, 7.06100e+03, 2.72000e+02, 1.00000e+00, 1.00000e+00]),
#  array([-5.79188121, -4.50000479, -3.20812837, -1.91625196, -0.62437554,
#          0.66750088,  1.95937729,  3.25125371,  4.54313013,  5.83500654,
#          7.12688296]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V14'], rwidth=0.8)
# Out:
# (array([1.00000e+01, 3.90000e+01, 7.40000e+01, 1.65000e+02, 4.31000e+02,
#         1.51290e+04, 2.59424e+05, 9.38900e+03, 1.42000e+02, 4.00000e+00]),
#  array([-19.21432549, -16.24021634, -13.26610718, -10.29199803,
#          -7.31788887,  -4.34377972,  -1.36967057,   1.60443859,
#           4.57854774,   7.5526569 ,  10.52676605]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V15'], rwidth=0.8)
# Out:
# (array([3.23000e+02, 9.07800e+03, 7.10230e+04, 1.52686e+05, 5.04660e+04,
#         1.19500e+03, 2.70000e+01, 8.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([-4.49894468, -3.16127605, -1.82360742, -0.48593879,  0.85172983,
#          2.18939846,  3.52706709,  4.86473572,  6.20240434,  7.54007297,
#          8.8777416 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V16'], rwidth=0.8)
# Out:
# (array([3.70000e+01, 6.50000e+01, 1.32000e+02, 1.26570e+04, 2.64745e+05,
#         7.15100e+03, 1.80000e+01, 1.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([-14.12985452, -10.98535791,  -7.84086131,  -4.69636471,
#          -1.5518681 ,   1.5926285 ,   4.7371251 ,   7.88162171,
#          11.02611831,  14.17061491,  17.31511152]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V17'], rwidth=0.8)
# Out:
# (array([9.00000e+00, 3.40000e+01, 3.40000e+01, 8.30000e+01, 6.20000e+01,
#         1.27000e+02, 9.58300e+03, 2.72306e+05, 2.50900e+03, 6.00000e+01]),
#  array([-25.16279937, -21.72116681, -18.27953425, -14.83790168,
#         -11.39626912,  -7.95463656,  -4.513004  ,  -1.07137144,
#           2.37026113,   5.81189369,   9.25352625]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V18'], rwidth=0.8)
# Out:
# (array([2.10000e+01, 3.00000e+01, 2.60000e+01, 1.22000e+02, 2.12900e+03,
#         4.08910e+04, 1.88705e+05, 5.05750e+04, 2.27600e+03, 3.20000e+01]),
#  array([-9.49874592, -8.04476441, -6.5907829 , -5.13680139, -3.68281988,
#         -2.22883837, -0.77485686,  0.67912465,  2.13310616,  3.58708767,
#          5.04106919]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V19'], rwidth=0.8)
# Out:
# (array([2.00000e+00, 2.00000e+00, 1.05000e+02, 2.63900e+03, 3.59630e+04,
#         1.76234e+05, 6.40140e+04, 5.11400e+03, 7.15000e+02, 1.90000e+01]),
#  array([-7.21352743, -5.93297754, -4.65242766, -3.37187777, -2.09132789,
#         -0.810778  ,  0.46977188,  1.75032177,  3.03087166,  4.31142154,
#          5.59197143]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V20'], rwidth=0.8)
# Out:
# (array([1.00000e+00, 0.00000e+00, 1.00000e+00, 2.90000e+01, 1.74000e+02,
#         2.79989e+05, 4.57200e+03, 3.50000e+01, 4.00000e+00, 2.00000e+00]),
#  array([-54.49772049, -45.10585802, -35.71399555, -26.32213307,
#         -16.9302706 ,  -7.53840812,   1.85345435,  11.24531683,
#          20.6371793 ,  30.02904177,  39.42090425]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V21'], rwidth=0.8)
# Out:
# (array([1.00000e+00, 4.00000e+00, 8.00000e+00, 5.10000e+01, 5.40000e+02,
#         2.82045e+05, 1.93100e+03, 1.88000e+02, 2.60000e+01, 1.30000e+01]),
#  array([-34.83038214, -28.62706001, -22.42373788, -16.22041575,
#         -10.01709362,  -3.81377149,   2.38955064,   8.59287277,
#          14.7961949 ,  20.99951703,  27.20283916]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V21'], rwidth=0.8)
# Out:
# (array([1.00000e+00, 4.00000e+00, 8.00000e+00, 5.10000e+01, 5.40000e+02,
#         2.82045e+05, 1.93100e+03, 1.88000e+02, 2.60000e+01, 1.30000e+01]),
#  array([-34.83038214, -28.62706001, -22.42373788, -16.22041575,
#         -10.01709362,  -3.81377149,   2.38955064,   8.59287277,
#          14.7961949 ,  20.99951703,  27.20283916]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['V22'], rwidth=0.8)
# Out:
# (array([8.00000e+00, 1.10000e+01, 4.50000e+01, 6.03000e+02, 1.11501e+05,
#         1.71906e+05, 6.94000e+02, 3.00000e+01, 7.00000e+00, 2.00000e+00]),
#  array([-10.9331437 ,  -8.78952032,  -6.64589694,  -4.50227356,
#          -2.35865018,  -0.2150268 ,   1.92859657,   4.07221995,
#           6.21584333,   8.35946671,  10.50309009]),
#  <a list of 10 Patch objects>)

# %%
plt.hist([data['Time'],data['V1']])
# Out:
# ([array([10498., 16852., 38556., 38575., 40260., 10182., 17140., 38956.,
#          40787., 33001.]),
#   array([284807.,      0.,      0.,      0.,      0.,      0.,      0.,
#               0.,      0.,      0.])],
#  array([-5.64075096e+01,  1.72284332e+04,  3.45132740e+04,  5.17981147e+04,
#          6.90829555e+04,  8.63677962e+04,  1.03652637e+05,  1.20937478e+05,
#          1.38222318e+05,  1.55507159e+05,  1.72792000e+05]),
#  <a list of 2 Lists of Patches objects>)

# %%
plt.hist([data['Time'],data['V2']])
# Out:
# ([array([10494., 16828., 38560., 38574., 40270., 10197., 17127., 38963.,
#          40785., 33009.]),
#   array([284807.,      0.,      0.,      0.,      0.,      0.,      0.,
#               0.,      0.,      0.])],
#  array([-7.27157276e+01,  1.72137558e+04,  3.45002274e+04,  5.17866990e+04,
#          6.90731706e+04,  8.63596421e+04,  1.03646114e+05,  1.20932585e+05,
#          1.38219057e+05,  1.55505528e+05,  1.72792000e+05]),
#  <a list of 2 Lists of Patches objects>)

# %%
plt.hist([data['Time'],data['V3']])
# Out:
# ([array([10501., 16858., 38560., 38575., 40254., 10175., 17142., 38957.,
#          40784., 33001.]),
#   array([284807.,      0.,      0.,      0.,      0.,      0.,      0.,
#               0.,      0.,      0.])],
#  array([-4.83255894e+01,  1.72357070e+04,  3.45197395e+04,  5.18037721e+04,
#          6.90878046e+04,  8.63718372e+04,  1.03655870e+05,  1.20939902e+05,
#          1.38223935e+05,  1.55507967e+05,  1.72792000e+05]),
#  <a list of 2 Lists of Patches objects>)

# %%
plt.hist([data['Time'],data['V4']])
# Out:
# ([array([10508., 16947., 38529., 38553., 40245., 10146., 17157., 38956.,
#          40779., 32987.]),
#   array([284807.,      0.,      0.,      0.,      0.,      0.,      0.,
#               0.,      0.,      0.])],
#  array([-5.68317120e+00,  1.72740851e+04,  3.45538535e+04,  5.18336218e+04,
#          6.91133901e+04,  8.63931584e+04,  1.03672927e+05,  1.20952695e+05,
#          1.38232463e+05,  1.55512232e+05,  1.72792000e+05]),
#  <a list of 2 Lists of Patches objects>)
